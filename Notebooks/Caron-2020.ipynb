# %% [markdown]
# # Caron

# %%
import scanpy as sc
import pandas as pd
import numpy as np

# %%
import os
os.chdir("/Users/randyramdial/Desktop/FoMR/Alternate Article/GSE132509_RAW")

# %%
sample_id = os.listdir()
sample_id
# Out:
# ['GSM3872434_ETV6-RUNX1_1.matrix.mtx.gz',
#  'GSM3872444_PBMMC_3.genes.tsv.gz',
#  'GSM3872442_PBMMC_1.genes.tsv.gz',
#  'GSM3872436_ETV6-RUNX1_3.matrix.mtx.gz',
#  'GSM3872438_HHD_1.genes.tsv.gz',
#  '.DS_Store',
#  'GSM3872439_HHD_2.genes.tsv.gz',
#  'GSM3872437_ETV6-RUNX1_4.matrix.mtx.gz',
#  'GSM3872436_ETV6-RUNX1_3.genes.tsv.gz',
#  'GSM3872435_ETV6-RUNX1_2.matrix.mtx.gz',
#  'GSM3872444_PBMMC_3.matrix.mtx.gz',
#  'GSM3872443_PBMMC_2.matrix.mtx.gz',
#  'GSM3872440_PRE-T_1.genes.tsv.gz',
#  'GSM3872437_ETV6-RUNX1_4.barcodes.tsv.gz',
#  'GSM3872441_PRE-T_2.matrix.mtx.gz',
#  'GSM3872444_PBMMC_3.barcodes.tsv.gz',
#  'GSM3872443_PBMMC_2.genes.tsv.gz',
#  'GSM3872436_ETV6-RUNX1_3.barcodes.tsv.gz',
#  'GSM3872438_HHD_1.matrix.mtx.gz',
#  'GSM3872434_ETV6-RUNX1_1.barcodes.tsv.gz',
#  'GSM3872441_PRE-T_2.barcodes.tsv.gz',
#  'GSM3872442_PBMMC_1.barcodes.tsv.gz',
#  'GSM3872439_HHD_2.matrix.mtx.gz',
#  'GSM3872437_ETV6-RUNX1_4.genes.tsv.gz',
#  'GSM3872443_PBMMC_2.barcodes.tsv.gz',
# ...

# %%
# Select only "genes.tsv.gz" files
selected_files = [filename for filename in sample_id if filename.endswith("genes.tsv.gz")]

print(selected_files)
# Out:
# ['GSM3872444_PBMMC_3.genes.tsv.gz', 'GSM3872442_PBMMC_1.genes.tsv.gz', 'GSM3872438_HHD_1.genes.tsv.gz', 'GSM3872439_HHD_2.genes.tsv.gz', 'GSM3872436_ETV6-RUNX1_3.genes.tsv.gz', 'GSM3872440_PRE-T_1.genes.tsv.gz', 'GSM3872443_PBMMC_2.genes.tsv.gz', 'GSM3872437_ETV6-RUNX1_4.genes.tsv.gz', 'GSM3872441_PRE-T_2.genes.tsv.gz', 'GSM3872435_ETV6-RUNX1_2.genes.tsv.gz', 'GSM3872434_ETV6-RUNX1_1.genes.tsv.gz']

# %%
features = pd.read_csv('/Users/randyramdial/Desktop/FoMR/Alternate Article/GSE132509_RAW/GSM3872434_ETV6-RUNX1_1.genes.tsv.gz', header=None, sep='\t')
features[2] = 'Gene Expression'
features.to_csv('/Users/randyramdial/Desktop/FoMR/Alternate Article/GSE132509_RAW/GSM3872434_ETV6-RUNX1_1.genes.tsv.gz', header=False, index=False , compression = 'gzip', sep = '\t')

# %%
import os
import shutil

def move_files_by_extension(source_folder, target_folder, file_extension):
    # Create the target folder if it doesn't exist
    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    # Get a list of files in the source folder
    files = os.listdir(source_folder)

    # Filter and move files with the desired file extension
    for filename in files:
        if filename.endswith(file_extension):
            source_file = os.path.join(source_folder, filename)
            target_file = os.path.join(target_folder, filename)
            shutil.move(source_file, target_file)

# Example usage:
source_folder = "/Users/randyramdial/Desktop/FoMR/Alternate Article/GSE132509_RAW"
target_folder = "/Users/randyramdial/Desktop/FoMR/Alternate Article/With Gene Expression"
file_extension = "genes.tsv.gz"

move_files_by_extension(source_folder, target_folder, file_extension)

# %%
import os
import pandas as pd

def process_and_save_files_in_folder(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Get a list of files in the input folder
    file_list = os.listdir(input_folder)

    for filename in file_list:
        # Check if the file is a CSV file
        if filename.endswith('genes.tsz.gz'):
            # Construct the full file paths for input and output files
            input_file_path = os.path.join(input_folder, filename)
            output_file_path = os.path.join(output_folder, filename.replace('genes.tsv.gz', '_modified.tsv.gz'))

            # Read the CSV file
            features = pd.read_csv(input_file_path, header=None, sep='\t')

            # Modify the DataFrame
            features[2] = 'Gene Expression'

            # Save the modified DataFrame to a compressed GZIP file
            features.to_csv(output_file_path, header=False, index=False, compression='gzip', sep='\t')

# Example usage:
input_folder = '/Users/randyramdial/Desktop/FoMR/Alternate Article/With Gene Expression'
output_folder = '/Users/randyramdial/Desktop/FoMR/Alternate Article/Processed Files'

process_and_save_files_in_folder(input_folder, output_folder)

# %%
import scanpy as sc
import pandas as pd
import numpy as np

# %%
import os
os.chdir("/Users/randyramdial/Desktop/FoMR/Alternate Article/GSE132509_RAW")

# %%
sample_id = os.listdir()
sample_id
# Out:
# ['GSM3872434_ETV6-RUNX1_1.matrix.mtx.gz',
#  'GSM3872436_ETV6-RUNX1_3.matrix.mtx.gz',
#  '.DS_Store',
#  'GSM3872437_ETV6-RUNX1_4.matrix.mtx.gz',
#  'GSM3872435_ETV6-RUNX1_2.matrix.mtx.gz',
#  'GSM3872444_PBMMC_3.matrix.mtx.gz',
#  'GSM3872443_PBMMC_2.matrix.mtx.gz',
#  'GSM3872437_ETV6-RUNX1_4.barcodes.tsv.gz',
#  'GSM3872441_PRE-T_2.matrix.mtx.gz',
#  'GSM3872444_PBMMC_3.barcodes.tsv.gz',
#  'GSM3872436_ETV6-RUNX1_3.barcodes.tsv.gz',
#  'GSM3872438_HHD_1.matrix.mtx.gz',
#  'GSM3872434_ETV6-RUNX1_1.barcodes.tsv.gz',
#  'GSM3872441_PRE-T_2.barcodes.tsv.gz',
#  'GSM3872442_PBMMC_1.barcodes.tsv.gz',
#  'GSM3872439_HHD_2.matrix.mtx.gz',
#  'GSM3872443_PBMMC_2.barcodes.tsv.gz',
#  'GSM3872440_PRE-T_1.barcodes.tsv.gz',
#  'GSM3872440_PRE-T_1.matrix.mtx.gz',
#  'GSM3872436_ETV6-RUNX1_3.matrix.mtx',
#  'GSM3872439_HHD_2.barcodes.tsv.gz',
#  'GSM3872435_ETV6-RUNX1_2.barcodes.tsv.gz',
#  'GSM3872438_HHD_1.barcodes.tsv.gz',
#  'GSM3872442_PBMMC_1.matrix.mtx.gz']

# %%
def process_and_save_files_in_folder(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Get a list of files in the input folder
    file_list = os.listdir(input_folder)

    for filename in file_list:
        # Check if the file is a CSV file
        if filename.endswith('genes.tsz.gz'):
            # Construct the full file paths for input and output files
            input_file_path = os.path.join(input_folder, filename)
            output_file_path = os.path.join(output_folder, filename.replace('genes.tsv.gz', '_modified.tsv.gz'))

            # Read the CSV file
            features = pd.read_csv(input_file_path, header=None, sep='\t')

            # Modify the DataFrame
            features[2] = 'Gene Expression'

            # Save the modified DataFrame to a compressed GZIP file
            features.to_csv(output_file_path, header=False, index=False, compression='gzip', sep='\t')

# Example usage:
input_folder = '/Users/randyramdial/Desktop/FoMR/Alternate Article/With Gene Expression'
output_folder = '/Users/randyramdial/Desktop/FoMR/Alternate Article/Processed Files'

process_and_save_files_in_folder(input_folder, output_folder)

# %%
import os
import pandas as pd

def process_and_save_files_in_folder(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Get a list of files in the input folder
    file_list = os.listdir(input_folder)

    for filename in file_list:
        print("Processing file:", filename)  # Add this line

        # Check if the file is a CSV file
        if filename.endswith('genes.tsv.gz'):
            # Construct the full file paths for input and output files
            input_file_path = os.path.join(input_folder, filename)
            output_file_path = os.path.join(output_folder, filename.replace('genes.tsv.gz', '_modified.tsv.gz'))

            # Read the CSV file
            features = pd.read_csv(input_file_path, header=None, sep='\t')

            # Modify the DataFrame
            features[2] = 'Gene Expression'

            # Save the modified DataFrame to a compressed GZIP file
            features.to_csv(output_file_path, header=False, index=False, compression='gzip', sep='\t')

# Example usage:
input_folder = '/Users/randyramdial/Desktop/FoMR/Alternate Article/With Gene Expression'
output_folder = '/Users/randyramdial/Desktop/FoMR/Alternate Article/Processed Files'

process_and_save_files_in_folder(input_folder, output_folder)
# Out:
# Processing file: GSM3872444_PBMMC_3.genes.tsv.gz
# Processing file: GSM3872442_PBMMC_1.genes.tsv.gz
# Processing file: GSM3872438_HHD_1.genes.tsv.gz
# Processing file: .DS_Store
# Processing file: GSM3872439_HHD_2.genes.tsv.gz
# Processing file: GSM3872436_ETV6-RUNX1_3.genes.tsv.gz
# Processing file: GSM3872440_PRE-T_1.genes.tsv.gz
# Processing file: GSM3872443_PBMMC_2.genes.tsv.gz
# Processing file: GSM3872437_ETV6-RUNX1_4.genes.tsv.gz
# Processing file: GSM3872441_PRE-T_2.genes.tsv.gz
# Processing file: GSM3872435_ETV6-RUNX1_2.genes.tsv.gz
# Processing file: GSM3872434_ETV6-RUNX1_1.genes.tsv.gz

# %%
adata = sc.read_10x_mtx("/Users/randyramdial/Desktop/FoMR/Alternate Article/1")

# %%
import scanpy as sc

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2776 × 33694
#     var: 'gene_ids', 'feature_types'

# %%
import scanpy as sc
import pandas as pd

# %%
adata = sc.read_10x_mtx('/Users/randyramdial/Desktop/FoMR/Caron 2020/434')
adata
# Out:
# AnnData object with n_obs × n_vars = 2776 × 33694
#     var: 'gene_ids', 'feature_types'

# %%
sc.pl.highest_expr_genes(adata, n_top=20, )

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
             jitter=0.4, multi_panel=True)
# Out:
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %%
adata = adata[adata.obs.n_genes_by_counts < 2500, :]
adata = adata[adata.obs.pct_counts_mt < 5, :]

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
# Out:
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
sc.pl.highly_variable_genes(adata)

# %%
adata.raw = adata

# %%
sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt'])

# %%
sc.pp.scale(adata, max_value=10)

# %%
sc.tl.pca(adata, svd_solver='arpack')

# %%
sc.pl.pca(adata, color='CST3')

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
adata.write_h5ad("/Users/randyramdial/Desktop/FoMR/Caron 2020.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 918 × 15545
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'hvg', 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)
# Out:
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# ...

# %%
import scanpy as sc
import pandas as pd

# %%
adata = sc.read_h5ad("/Users/randyramdial/Desktop/FoMR/Caron 2020.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 918 × 15545
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'hvg', 'log1p', 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 918 × 15545
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'hvg', 'log1p', 'pca', 'neighbors'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
# Assuming 'adata' is loaded with your dataset
sc.tl.leiden(adata)

# %%
sc.tl.paga(adata)
sc.pl.paga(adata, plot=False)  # remove `plot=False` if you want to see the coarse-grained graph
sc.tl.umap(adata, init_pos='paga')

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=['CST3', 'NKG7'])

# %%
sc.pl.umap(adata, color=['CST3', 'NKG7'], use_raw=False)

# %%
sc.tl.leiden(adata)

# %%
sc.pl.umap(adata, color=['leiden', 'CST3', 'NKG7'])
# Out:
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata.write_h5ad("/Users/randyramdial/Desktop/FoMR/Caron 2020.h5ad")

# %%
sc.tl.rank_genes_groups(adata, 'leiden', method='t-test')
sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 sc.tl.rank_genes_groups(adata, 'leiden', method='t-test')
#       2 sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)
#
# File ~/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/scanpy/tools/_rank_genes_groups.py:590, in rank_genes_groups(adata, groupby, use_raw, groups, reference, n_genes, rankby_abs, pts, key_added, copy, method, corr_method, tie_correct, layer, **kwds)
#     580 adata.uns[key_added] = {}
#     581 adata.uns[key_added]['params'] = dict(
#     582     groupby=groupby,
#     583     reference=reference,
#    (...)
#     587     corr_method=corr_method,
#     588 )
# --> 590 test_obj = _RankGenes(adata, groups_order, groupby, reference, use_raw, layer, pts)
#     592 if check_nonnegative_integers(test_obj.X) and method != 'logreg':
#     593     logg.warning(
# ...

# %%
# Load your AnnData object
adata = sc.read_h5ad("/Users/randyramdial/Desktop/FoMR/Caron 2020.h5ad")

# Logarithmize the data
sc.pp.log1p(adata)

# Perform Leiden clustering
sc.tl.leiden(adata)

# Perform gene ranking analysis
sc.tl.rank_genes_groups(adata, 'leiden', method='t-test')

# Visualize gene ranking results
sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)
# Out:
# WARNING: adata.X seems to be already log-transformed.
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/scanpy/preprocessing/_simple.py:352: RuntimeWarning: invalid value encountered in log1p
#   np.log1p(X, out=X)

# %%
sc.settings.verbosity = 2  # reduce the verbosity

# %%
sc.tl.rank_genes_groups(adata, 'leiden', method='wilcoxon')
sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)
# Out:
# ranking genes
#     finished (0:00:03)

# %%
adata.write_h5ad("/Users/randyramdial/Desktop/FoMR/Caron 2020.h5ad")

# %%
sc.tl.rank_genes_groups(adata, 'leiden', method='logreg')
sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)
# Out:
# ranking genes
#     finished (0:00:13)
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
marker_genes = ['IL7R', 'CD79A', 'MS4A1', 'CD8A', 'CD8B', 'LYZ', 'CD14',
                'LGALS3', 'S100A8', 'GNLY', 'NKG7', 'KLRB1',
                'FCGR3A', 'MS4A7', 'FCER1A', 'CST3', 'PPBP']

# %%
adata = sc.read("/Users/randyramdial/Desktop/FoMR/Caron 2020.h5ad")

# %%
pd.DataFrame(adata.uns['rank_genes_groups']['names']).head(5)
# Out:
#           0      1          2              3      4       5        6        7  \
# 0      CYGB   TYMS  LINC01013  RP11-301G19.1  RPS19   RPL28    HMGB2   TAGLN2
# 1  HIST1H1C  GINS2      TERF2         PDLIM1   RPS2   HEMGN    HMGB1      VIM
# 2       NPY   MCM7     TMSB10           LEF1  CD79A   RPS20    PTTG1     CD27
# 3    VPREB3   PCNA       CTGF          TCL1A  RPS24  RPL13A  ARL6IP1    CLIC1
# 4      LST1  H2AFZ      STAG3        C1QTNF4  RPS12   RPS15    HMGN2  TSC22D3
#
#         8       9        10
# 0    IL32   RPS3A      HBA2
# 1     B2M   RPLP0     ALAS2
# 2    HCST  RPL13A      HBA1
# 3   RPL21  RPL27A       HBB
# 4  MALAT1   RPS19  SLC25A37

# %%
result = adata.uns['rank_genes_groups']
groups = result['names'].dtype.names
pd.DataFrame(
    {group + '_' + key[:1]: result[key][group]
    for group in groups for key in ['names', 'pvals']}).head(5)
# Out:
#         0_n           0_p    1_n           1_p        2_n           2_p  \
# 0      CYGB  8.355509e-23   TYMS  3.088928e-50  LINC01013  3.080590e-25
# 1  HIST1H1C  1.209117e-22  GINS2  1.219757e-44      TERF2  7.002876e-24
# 2       NPY  2.696531e-19   MCM7  3.781913e-44     TMSB10  1.021111e-23
# 3    VPREB3  7.826507e-19   PCNA  3.178625e-42       CTGF  2.488900e-22
# 4      LST1  1.273853e-16  H2AFZ  4.001568e-40      STAG3  2.127187e-20
#
#              3_n           3_p    4_n           4_p  ...      6_n  \
# 0  RP11-301G19.1  3.665049e-19  RPS19  1.438629e-18  ...    HMGB2
# 1         PDLIM1  2.748827e-16   RPS2  3.458809e-17  ...    HMGB1
# 2           LEF1  6.103703e-15  CD79A  2.507445e-16  ...    PTTG1
# 3          TCL1A  6.929286e-15  RPS24  5.126523e-16  ...  ARL6IP1
# 4        C1QTNF4  3.869869e-14  RPS12  5.634651e-16  ...    HMGN2
#
#             6_p      7_n           7_p     8_n           8_p     9_n  \
# ...

# %%
sc.tl.rank_genes_groups(adata, 'leiden', groups=['0'], reference='1', method='wilcoxon')
sc.pl.rank_genes_groups(adata, groups=['0'], n_genes=20)
# Out:
# ranking genes
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 sc.tl.rank_genes_groups(adata, 'leiden', groups=['0'], reference='1', method='wilcoxon')
#       2 sc.pl.rank_genes_groups(adata, groups=['0'], n_genes=20)
#
# File ~/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/scanpy/tools/_rank_genes_groups.py:590, in rank_genes_groups(adata, groupby, use_raw, groups, reference, n_genes, rankby_abs, pts, key_added, copy, method, corr_method, tie_correct, layer, **kwds)
#     580 adata.uns[key_added] = {}
#     581 adata.uns[key_added]['params'] = dict(
#     582     groupby=groupby,
#     583     reference=reference,
#    (...)
#     587     corr_method=corr_method,
#     588 )
# --> 590 test_obj = _RankGenes(adata, groups_order, groupby, reference, use_raw, layer, pts)
# ...

# %%
# Load your AnnData object
adata = sc.read_h5ad("/Users/randyramdial/Desktop/FoMR/Caron 2020.h5ad")

# Logarithmize the data
sc.pp.log1p(adata)

# Perform Leiden clustering
sc.tl.leiden(adata)

# Perform gene ranking analysis
sc.tl.rank_genes_groups(adata, groupby='leiden', groups=['0'], reference='1', method='wilcoxon')

# Visualize gene ranking results
sc.pl.rank_genes_groups(adata, groups=['0'], n_genes=20)
# Out:
# WARNING: adata.X seems to be already log-transformed.
# running Leiden clustering
#     finished (0:00:00)
# ranking genes
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/scanpy/preprocessing/_simple.py:352: RuntimeWarning: invalid value encountered in log1p
#   np.log1p(X, out=X)
#     finished (0:00:00)

# %%
sc.pl.rank_genes_groups_violin(adata, groups='0', n_genes=8)
# Out:
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
adata = sc.read("/Users/randyramdial/Desktop/FoMR/Caron 2020.h5ad")

# %%
sc.pl.rank_genes_groups_violin(adata, groups='0', n_genes=8)
# Out:
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
sc.pl.violin(adata, ['CST3', 'NKG7'], groupby='leiden')

# %%
new_cluster_names = [
    'CD4 T', 'CD14 Monocytes',
    'B', 'CD8 T',
    'NK', 'FCGR3A Monocytes',
    'Dendritic', 'Megakaryocytes',
    '9', '10', '11']
adata.rename_categories('leiden', new_cluster_names)

# %%
sc.pl.umap(adata, color='leiden', legend_loc='on data', title='', frameon=False, save='.pdf')
# Out:
# WARNING: saving figure to file figures/umap.pdf
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.dotplot(adata,['CD14', 'CD19', 'CD4', 'CD8B' ], groupby='leiden')
# Out:
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.stacked_violin(adata, ['CD14', 'CD19', 'CD4', 'CD8B' ], groupby='leiden', rotation=90);

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 918 × 15545
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'hvg', 'leiden', 'leiden_colors', 'leiden_sizes', 'log1p', 'neighbors', 'paga', 'pca', 'rank_genes_groups', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata.write_h5ad("/Users/randyramdial/Desktop/FoMR/Caron 2020.h5ad", compression='gzip')
