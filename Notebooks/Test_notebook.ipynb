# %%
# !pip install scanpy
# Out:
# 555.05s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...

# %%
# !pip install scanpy
# Out:
# 568.15s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...

# %%
import scanpy as sc

# %%
adata = sc.read_text('/Users/randyramdial/Desktop/FoMR/GSM3588005_OCI-AML3.dem.txt').T
adata
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 adata = sc.read_text('/Users/randyramdial/Desktop/FoMR/GSM3588005_OCI-AML3.dem.txt').T
#       2 adata
#
# File ~/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/anndata/_io/read.py:358, in read_text(filename, delimiter, first_column_names, dtype)
#     356         return _read_text(f, delimiter, first_column_names, dtype)
#     357 else:
# --> 358     with filename.open() as f:
#     359         return _read_text(f, delimiter, first_column_names, dtype)
#
# File ~/anaconda3/envs/MEDI7281/lib/python3.11/pathlib.py:1044, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1042 if "b" not in mode:
#    1043     encoding = io.text_encoding(encoding)
# -> 1044 return io.open(self, mode, buffering, encoding, errors, newline)
#
# ...

# %%
import os

file_path = '/Users/randyramdial/desktop/FoMR/GSE116256_RAW/GSM3588005_OCI-AML3.dem.txt'
print(os.path.exists(file_path))
# Out:
# True

# %%
adata = sc.read_text('/Users/randyramdial/desktop/FoMR/GSE116256_RAW/GSM3588005_OCI-AML3.dem.txt').T
adata
# Out:
# AnnData object with n_obs × n_vars = 1178 × 27899

# %%
# !pip install scanpy

# %%
import scanpy as sc

# %%
adata = sc.read_text('/Users/randyramdial/desktop/FoMR/GSE116256_RAW/GSM3588005_OCI-AML3.dem.txt').T
adata
# Out:
# AnnData object with n_obs × n_vars = 1178 × 27899

# %%
adata.X.shape
# Out:
# (1178, 27899)

# %% [markdown]
# Doublet Removal

# %%
 # !pip install scvi-tools
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 351.0/351.0 kB 701.2 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.6/89.6 kB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.9/225.9 kB 1.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 1.3 MB/s eta 0:00:0000:0100:010m
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 MB 566.0 kB/s eta 0:00:0000:0100:03
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 603.0 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 1.0 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.6/304.6 kB 519.0 kB/s eta 0:00:00a 0:00:01
# ...

# %%
import scvi
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import scvi
#
# ModuleNotFoundError: No module named 'scvi'

# %%
# !pip install --upgrade pip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 194.9 kB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.1.2
#     Uninstalling pip-23.1.2:
#       Successfully uninstalled pip-23.1.2
# ...

# %%
pip install scvi
# Out:
# ...
#   Using cached scvi-0.6.8-py2.py3-none-any.whl (158 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 MB 1.1 MB/s eta 0:00:0000:0100:03
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 623.1 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.2/115.2 kB 1.8 MB/s eta 0:00:0000:01
# ...
#   Obtaining dependency information for scikit-misc>=0.1.3 from https://files.pythonhosted.org/packages/47/32/7e539471b62b2c2930a09bc667ba3a6971b41fad1c30bf67d904e70ab753/scikit_misc-0.3.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata
# ...
#   Obtaining dependency information for pymongo from https://files.pythonhosted.org/packages/e2/80/4c06e57d6ea4d781867f5e6b0531b69a3115d4c06af211da1a21bdde0f8d/pymongo-4.4.1-cp311-cp311-macosx_10_9_universal2.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 1.3 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...

# %%
import scvi
# Out:
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/scvi/__init__.py:31: DeprecationWarning: scvi is deprecated, please uninstall scvi via `pip uninstall scvi` and install the new scvi-tools package at github.com/YosefLab/scvi-tools
#   warnings.warn(deprecation_msg, DeprecationWarning)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1178 × 27899

# %%
sc.pp.filter_genes(adata, min_cells = 10)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1178 × 27899

# %%
sc.pp.highly_variable_genes(adata, n_top_genes = 2000, subset = True, flavor = 'seurat_v3')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1178 × 27899

# %%
import numpy as np
import pandas as pd
import scanpy as sc

# %%
# !pip install scvi-tools
# Out:
# ...
#   Obtaining dependency information for scvi-tools from https://files.pythonhosted.org/packages/ce/7d/13ef7fc775387b588268b210bde63c59d546bd7ed263214b6a9fecf4a1da/scvi_tools-1.0.2-py3-none-any.whl.metadata
# ...
#   Using cached chex-0.1.7-py3-none-any.whl (89 kB)
# ...
#   Using cached docrep-0.3.2.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Obtaining dependency information for flax from https://files.pythonhosted.org/packages/bb/1d/d9dccc3b42aab0713f72f68c0de2b3b58c8a9f81e117fa95e02e66678499/flax-0.7.0-py3-none-any.whl.metadata
# ...
#   Using cached jax-0.4.13.tar.gz (1.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Obtaining dependency information for jaxlib>=0.4.3 from https://files.pythonhosted.org/packages/02/e2/803075c7ad869b47b40e08b7fad35916f4536d3e6df40c02e38d7e0cf0d5/jaxlib-0.4.13-cp311-cp311-macosx_10_14_x86_64.whl.metadata
# ...

# %%
import scvi

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1178 × 27899

# %%
sc.pp.filter_genes(adata, min_cells = 10)
sc.pp.highly_variable_genes(adata, n_top_genes = 2000, subset = True, flavor = 'seurat_v3')
adata
# Out:
# AnnData object with n_obs × n_vars = 1178 × 2000
#     var: 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'hvg'

# %%
pip install scvi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
scvi.model.SCVI.setup_anndata(adata)
vae = scvi.model.SCVI(adata)
vae.train()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 scvi.model.SCVI.setup_anndata(adata)
#       2 vae = scvi.model.SCVI(adata)
#       3 vae.train()
#
# AttributeError: module 'scvi' has no attribute 'model'

# %%
# !pip uninstall --yes scvi-tools
# Out:
# Found existing installation: scvi-tools 1.0.2
# Uninstalling scvi-tools-1.0.2:
#   Successfully uninstalled scvi-tools-1.0.2

# %%
# !conda install scvi-tools -c conda-forge
Y
# Out:
# ...
# Solving environment: |
# ...
#   - conda-forge/noarch::pyparsing-3.1.0-pyhd8ed1ab_0, conda-forge/osx-64::matplotlib-base-3.7.1-py311h2bf763f_0
#   - conda-forge/noarch::pyparsing-3.0.9-pyhd8ed1ab_0, conda-forge/osx-64::matplotlib-base-3.7.2-py311haff9b01done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.2
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/randyramdial/anaconda3/envs/MEDI7281
#
#   added / updated specs:
#     - scvi-tools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     absl-py-1.4.0              |     pyhd8ed1ab_0         100 KB  conda-forge
# ...

# %%
# !conda update -n base -c defaults conda
# Out:
# ...
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::holoviews==1.15.4=py310hecd8cb5_0
#   - defaults/osx-64::intake==0.6.7=py310hecd8cb5_0
#   - defaults/osx-64::seaborn==0.12.2=py310hecd8cb5_0
#   - defaults/osx-64::xarray==2022.11.0=py310hecd8cb5_0
#   - defaults/osx-64::datashader==0.14.4=py310hecd8cb5_0
#   - defaults/osx-64::hvplot==0.8.2=py310hecd8cb5_0
#   - defaults/osx-64::statsmodels==0.13.5=py310h7b7cdfe_1
#   - defaults/osx-64::dask==2022.7.0=py310hecd8cb5_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/randyramdial/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.12.2      |  py310hecd8cb5_0         218 KB
# ...

# %%
# !conda install -c conda-forge scvi
# !conda install pytorch torchvision torchaudio c-pytorch
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - scvi
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/osx-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# ...

# %%
# !conda install scvi-tools -c conda-forge
# Out:
# ...
# Solving environment: |
# ...
#   - conda-forge/noarch::pyparsing-3.1.0-pyhd8ed1ab_0, conda-forge/osx-64::matplotlib-base-3.7.1-py311h2bf763f_0
#   - conda-forge/noarch::pyparsing-3.0.9-pyhd8ed1ab_0, conda-forge/osx-64::matplotlib-base-3.7.2-py311haff9b01done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.2
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/randyramdial/anaconda3/envs/MEDI7281
#
#   added / updated specs:
#     - scvi-tools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     absl-py-1.4.0              |     pyhd8ed1ab_0         100 KB  conda-forge
# ...

# %%
scvi.model.SCVI.setup_anndata(adata)
vae = scvi.model.SCVI(adata)
vae.train()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 scvi.model.SCVI.setup_anndata(adata)
#       2 vae = scvi.model.SCVI(adata)
#       3 vae.train()
#
# AttributeError: module 'scvi' has no attribute 'model'

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# ...

# %%
results_file = 'write/pbmc3k.h5ad'

# %%
adata = sc.read_text(
    '/Users/randyramdial/desktop/FoMR/GSE116256_RAW/GSM3588005_OCI-AML3.dem.txt',  # the directory with the `.mtx` file
    var_names='gene_symbols',                # use gene symbols for the variable names (variables-axis index)
    cache=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 adata = sc.read_text(
#       2     '/Users/randyramdial/desktop/FoMR/GSE116256_RAW/GSM3588005_OCI-AML3.dem.txt',  # the directory with the `.mtx` file
#       3     var_names='gene_symbols',                # use gene symbols for the variable names (variables-axis index)
#       4     cache=True)
#
# TypeError: read_text() got an unexpected keyword argument 'var_names'

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1178 × 2000
#     var: 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'hvg'

# %%
adata = sc.read_text('/Users/randyramdial/desktop/FoMR/GSE116256_RAW/GSM3588005_OCI-AML3.dem.txt')

# %%
adata = sc.read_text('/Users/randyramdial/desktop/FoMR/GSE116256_RAW/GSM3588005_OCI-AML3.dem.txt')  # the directory with the `.mtx` fil
var_names='gene_symbols'                # use gene symbols for the variable names (variables-axis index
cache=True

# %%
adata.var_names_make_unique()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 27899 × 1178

# %%
adata.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [A1BG, A1BG-AS1, A1CF, A2M, A2M-AS1, A2ML1, A2MP1, A3GALT2, A4GALT, A4GNT, AA06, AAAS, AACS, AACSP1, AADAC, AADACL2, AADACL2-AS1, AADACL3, AADACL4, AADACP1, AADAT, AAED1, AAGAB, AAK1, AAMDC, AAMP, AANAT, AAR2, AARD, AARS, AARS2, AARSD1, AASDH, AASDHPPT, AASS, AATBC, AATF, AATK, AATK-AS1, ABALON, ABAT, ABCA1, ABCA10, ABCA11P, ABCA12, ABCA13, ABCA17P, ABCA2, ABCA3, ABCA4, ABCA5, ABCA6, ABCA7, ABCA8, ABCA9, ABCA9-AS1, ABCB1, ABCB10, ABCB11, ABCB4, ABCB5, ABCB6, ABCB7, ABCB8, ABCB9, ABCC1, ABCC10, ABCC11, ABCC12, ABCC13, ABCC2, ABCC3, ABCC4, ABCC5, ABCC5-AS1, ABCC6, ABCC6P1, ABCC6P2, ABCC8, ABCC9, ABCD1, ABCD2, ABCD3, ABCD4, ABCE1, ABCF1, ABCF2, ABCF3, ABCG1, ABCG2, ABCG4, ABCG5, ABCG8, ABHD1, ABHD10, ABHD11, ABHD11-AS1, ABHD12, ABHD12B, ABHD13, ...]
#
# [27899 rows x 0 columns]

# %%
adata.var[adata.var.index.str.startswith('MT-')]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd

# %%
ribo_url = "http://software.broadinstitute.org/gsea/msigdb/download_geneset.jsp?geneSetName=KEGG_RIBOSOME&fileType=text"

# %%
ribo_genes = pd.read_table(ribo_url, skiprows=2, header = None)
ribo_genes
# Out:
#              0
# 0          FAU
# 1       MRPL13
# 2        RPL10
# 3       RPL10A
# 4       RPL10L
# ..         ...
# 83        RPS9
# 84        RPSA
# 85     RSL24D1
# 86  RSL24D1P11
# 87       UBA52
#
# [88 rows x 1 columns]

# %%
adata.var['ribo'] = adata.var_names.isin(ribo_genes[0].values)

# %%
adata.var
# Out:
#                         ribo
# OCI-AML3_AAAAAGTATGGG  False
# OCI-AML3_AAAAGACGACGG  False
# OCI-AML3_AAAATCTTTCCT  False
# OCI-AML3_AAAATGCATTTN  False
# OCI-AML3_AAAATTTTCCGC  False
# ...                      ...
# OCI-AML3_TTTGAGCCAACC  False
# OCI-AML3_TTTGCCACAGGC  False
# OCI-AML3_TTTTATGAATTN  False
# OCI-AML3_TTTTGACTTTTN  False
# OCI-AML3_TTTTGTGACCGT  False
#
# [1178 rows x 1 columns]

# %%
adata.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [A1BG, A1BG-AS1, A1CF, A2M, A2M-AS1, A2ML1, A2MP1, A3GALT2, A4GALT, A4GNT, AA06, AAAS, AACS, AACSP1, AADAC, AADACL2, AADACL2-AS1, AADACL3, AADACL4, AADACP1, AADAT, AAED1, AAGAB, AAK1, AAMDC, AAMP, AANAT, AAR2, AARD, AARS, AARS2, AARSD1, AASDH, AASDHPPT, AASS, AATBC, AATF, AATK, AATK-AS1, ABALON, ABAT, ABCA1, ABCA10, ABCA11P, ABCA12, ABCA13, ABCA17P, ABCA2, ABCA3, ABCA4, ABCA5, ABCA6, ABCA7, ABCA8, ABCA9, ABCA9-AS1, ABCB1, ABCB10, ABCB11, ABCB4, ABCB5, ABCB6, ABCB7, ABCB8, ABCB9, ABCC1, ABCC10, ABCC11, ABCC12, ABCC13, ABCC2, ABCC3, ABCC4, ABCC5, ABCC5-AS1, ABCC6, ABCC6P1, ABCC6P2, ABCC8, ABCC9, ABCD1, ABCD2, ABCD3, ABCD4, ABCE1, ABCF1, ABCF2, ABCF3, ABCG1, ABCG2, ABCG4, ABCG5, ABCG8, ABHD1, ABHD10, ABHD11, ABHD11-AS1, ABHD12, ABHD12B, ABHD13, ...]
#
# [27899 rows x 0 columns]

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts'], jitter=0.4, multi_panel=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts'], jitter=0.4, multi_panel=True)
#
# File ~/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/scanpy/plotting/_anndata.py:781, in violin(adata, keys, groupby, log, use_raw, stripplot, jitter, size, layer, scale, order, multi_panel, xlabel, ylabel, rotation, show, save, ax, **kwds)
#     777         kwds['palette'] = dict(
#     778             zip(obs_df[groupby].cat.categories, adata.uns[f'{groupby}_colors'])
#     779         )
#     780 else:
# --> 781     obs_df = get.obs_df(adata, keys=keys, layer=layer, use_raw=use_raw)
#     782 if groupby is None:
#     783     obs_tidy = pd.melt(obs_df, value_vars=keys)
#
# ...

# %%
sc.pl.highest_expr_genes(adata, n_top=20, )
# Out:
# normalizing counts per cell
# /Users/randyramdial/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/scanpy/preprocessing/_normalization.py:197: UserWarning: Some cells have zero counts
#   warn(UserWarning('Some cells have zero counts'))
#     finished (0:00:00)

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
# Out:
# filtered out 24715 cells that have less than 200 genes expressed

# %%
sc.pl.violin(adata, ['n_genes_by_counts'],
jitter=0.4, multi_panel=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 sc.pl.violin(adata, ['n_genes_by_counts'],
#       2 jitter=0.4, multi_panel=True)
#
# File ~/anaconda3/envs/MEDI7281/lib/python3.11/site-packages/scanpy/plotting/_anndata.py:781, in violin(adata, keys, groupby, log, use_raw, stripplot, jitter, size, layer, scale, order, multi_panel, xlabel, ylabel, rotation, show, save, ax, **kwds)
#     777         kwds['palette'] = dict(
#     778             zip(obs_df[groupby].cat.categories, adata.uns[f'{groupby}_colors'])
#     779         )
#     780 else:
# --> 781     obs_df = get.obs_df(adata, keys=keys, layer=layer, use_raw=use_raw)
#     782 if groupby is None:
#     783     obs_tidy = pd.melt(obs_df, value_vars=keys)
#
# ...
